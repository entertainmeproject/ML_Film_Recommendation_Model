# %%
import pandas as pd

# %% [markdown]
# Load Dataset

# %%
file_path = 'film_complete.csv'
df = pd.read_csv(file_path)

df.head()
# Out:
#            movie_name  year  runtime     genre  rating            director  \
# 0  Knock at the Cabin  2023  100 min    Horror     6.4  M. Night Shyamalan
# 1  Knock at the Cabin  2023  100 min   Mystery     6.4  M. Night Shyamalan
# 2  Knock at the Cabin  2023  100 min  Thriller     6.4  M. Night Shyamalan
# 3            The Menu  2022  107 min    Horror     7.2          Mark Mylod
# 4            The Menu  2022  107 min  Thriller     7.2          Mark Mylod
#
#                                                 star     votes
# 0  Dave Bautista, \nJonathan Groff, \nRupert Grin...   17991.0
# 1  Dave Bautista, \nJonathan Groff, \nRupert Grin...   17991.0
# 2  Dave Bautista, \nJonathan Groff, \nRupert Grin...   17991.0
# 3  Ralph Fiennes, \nAnya Taylor-Joy, \nNicholas H...  232052.0
# 4  Ralph Fiennes, \nAnya Taylor-Joy, \nNicholas H...  232052.0

# %%
genre_counts = df['genre'].value_counts()
print(genre_counts)
# Out:
# genre
# Horror        18681
# Thriller       4974
# Drama          3738
# Comedy         3225
# Mystery        2867
# Action         1879
# Fantasy        1622
# Sci-Fi         1583
# Crime          1186
# Adventure       908
# Romance         364
# Animation       191
# Family          124
# Musical          79
# Music            65
# Western          64
# History          50
# Biography        39
# War              32
# Film-Noir        12
# Sport            10
# Reality-TV        1
# Name: count, dtype: int64

# %% [markdown]
# Preprocessing

# %%
df['runtime'] = df['runtime'].str.replace(' min', '')
df['runtime'] = df['runtime'].str.replace(',', '')
df = df[df['year'] != 'I']

# %%
print(df['year'].unique())
print(df['runtime'].unique())
print(df['rating'].unique())
print(df['votes'].unique())
# Out:
# ['2023' '2022' '2000' '2021' '2019' '2018' '2016' '2017' '1996' '1979'
#  '2015' '2011' '1954' '1980' '2010' '2014' '2020' '2013' '1997' '2002'
#  '1987' '2009' '1982' '2007' '1993' '1973' '1960' '2008' '1981' '2004'
#  '1992' '2005' '1999' '1994' '2001' '1998' '1975' '1988' '2012' '2003'
#  '1986' '1976' '2006' '1968' '1978' '1984' '1989' '1974' '1983' '1977'
#  '1990' '1985' '1995' '1963' '1962' '1922' '1972' '1932' '1920' '1933'
#  '1966' '1951' '1991' '1931' '1956' '1921' '1955' '1958' '1967' '1970'
#  '1965' '1959' '1964' '1953' '1971' '1957' '1935' '1942' '1961' '1945'
#  '1928' '1925' '1943' '1941' '1949' '1969' '1948' '1944' '1936' '1939'
#  '1946' '1926' '1934' '1923' '1911' '1940' '1927' '1952' '1924' '1913'
#  '1914' '1947' '1919' '1930' '1950' '1937' '1918' '1917' '1929' '1938'
#  '1916' '1915' '1912']
# ['100' '107' '102' '97' '117' '128' '105' '84' '108' '103' '115' '130'
#  '88' '131' '114' '148' '127' '136' '138' '83' '104' '111' '94' '126' '93'
#  '116' '95' '132' '79' '146' '90' '135' '101' '99' '121' '129' '92' '96'
#  '91' '76' '112' '113' '152' '123' '109' '98' '85' '122' '120' '118' '124'
#  '106' '87' '86' '110' '169' '156' '137' '134' '144' '89' '82' '75' '80'
#  '125' '81' '119' '78' '191' '71' '77' '57' '64' '67' '142' '73' '70' '72'
#  '74' '63' '172' '47' '62' '158' '60' '52' '183' '68' '66' '143' '170'
#  '65' '151' '50' '69' '133' '149' '48' '141' '61' '53' '54' '11' '45' '58'
#  '140' '159' '145' '56' '150' '369' '49' '160' '46' '163' '55' '265' '51'
#  '7' '155' '44' '139' '31' '192' '59' '171' '398' '175' '184' '354' '161'
#  '166' '177' '240' '208' '147' '165' '203' '198' '164' '224' '180' '281'
#  '222' '153' '162' '168' '225' '173' '248' '250' '194' '235' '186' '360'
#  '154' '1440' '167' '157' '675' '26' '300' '16' '278']
# [6.4 7.2 5.1 6.5 6.6 4.7 5.3 7.  6.9 2.5 6.3 7.6 5.8 7.1 7.3 5.7 5.5 6.2
#  6.1 7.7 7.4 5.6 8.5 8.4 6.  7.5 5.  5.9 6.8 5.2 4.9 2.6 5.4 6.7 8.2 3.5
#  8.1 7.8 4.4 3.  4.6 7.9 4.5 4.8 8.  2.1 3.8 4.  3.9 3.3 4.2 4.1 2.8 4.3
#  3.7 2.9 3.2 2.3 1.7 3.6 3.4 3.1 2.4 1.6 8.7 2.7 1.9 1.5 1.4 8.8 2.  9.2
#  1.8 1.3 2.2 8.9 9.  9.6 8.6 9.3 8.3 9.1 9.4 9.5 1.2 1.1 1. ]
# [ 17991. 232052.  62458. ...   3926.   2183.   1255.]

# %%
def reduce_genre_random(df, max_count=1500):
    grouped = df.groupby('genre')

    df = pd.DataFrame(columns=df.columns)

    for name, group in grouped:
        if len(group) > max_count:
            group = group.sample(n=max_count, random_state=42)
        df = pd.concat([df, group])

    return df

df = reduce_genre_random(df, max_count=4000)

print(df['genre'].value_counts())
# Out:
# genre
# Horror        4000
# Thriller      4000
# Drama         3738
# Comedy        3224
# Mystery       2867
# Action        1879
# Fantasy       1622
# Sci-Fi        1583
# Crime         1186
# Adventure      908
# Romance        364
# Animation      191
# Family         124
# Musical         79
# Music           65
# Western         64
# History         50
# Biography       39
# War             32
# Film-Noir       12
# Sport           10
# Reality-TV       1
# Name: count, dtype: int64

# %%
df.fillna('', inplace=True)
df['combined_features'] = df['genre'] + ' ' + df['director'] + ' ' + df['star']

df['year'] = pd.to_numeric(df['year'], errors='coerce')
df['runtime'] = pd.to_numeric(df['runtime'], errors='coerce')
df['rating'] = pd.to_numeric(df['rating'], errors='coerce')
df['votes'] = pd.to_numeric(df['votes'], errors='coerce')

from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(stop_words='english')
tfidf_matrix = tfidf.fit_transform(df['combined_features'])

# %%
df.to_csv('/content/film_dataset.csv', index=False)

# %%
from sklearn.metrics.pairwise import cosine_similarity

def get_similarity_score(user_input, tfidf_matrix):
    user_input_transformed = tfidf.transform(user_input['combined_features'])
    cosine_sim = cosine_similarity(user_input_transformed, tfidf_matrix)
    return cosine_sim[0]

# %%
def get_recommendations(user_input, tfidf_matrix, df):
    filtered_data = df[
        (df['genre'].str.contains(user_input['genre'][0], case=False)) &
        (df['year'] >= user_input['year'][0]) &
        (df['runtime'] <= user_input['runtime'][0]) &
        (df['rating'] >= user_input['rating'][0]) &
        (df['votes'] >= user_input['votes'][0])
    ].reset_index(drop=True)

    if len(filtered_data) >= 8:
        similarity_scores = get_similarity_score(user_input, tfidf_matrix[filtered_data.index])
        filtered_data['similarity_score'] = similarity_scores
        filtered_data = filtered_data.sort_values(by='similarity_score', ascending=False)
        recommendations = filtered_data.head(8).to_dict(orient='records')
    else:
        additional_data = df[df['genre'].str.contains(user_input['genre'][0], case=False)]
        additional_data = additional_data[~additional_data.index.isin(filtered_data.index)].reset_index(drop=True)
        additional_similarity_scores = get_similarity_score(user_input, tfidf_matrix[additional_data.index])
        additional_data['similarity_score'] = additional_similarity_scores
        additional_data = additional_data.sort_values(by='similarity_score', ascending=False)
        remaining_count = 8 - len(filtered_data)
        if remaining_count > 0:
            additional_recommendations = additional_data.head(remaining_count).to_dict(orient='records')
            recommendations = filtered_data.to_dict(orient='records') + additional_recommendations
        else:
            recommendations = filtered_data.to_dict(orient='records')

    return recommendations

dummy_data = pd.DataFrame({
    'year': [2000],
    'runtime': [200],
    'genre': ['Action'],
    'rating': [6.0],
    'director': [''],
    'star': [''],
    'votes': [1000]
})
dummy_data['combined_features'] = dummy_data['genre'] + ' ' + dummy_data['director'] + ' ' + dummy_data['star']

recommendations = get_recommendations(dummy_data, tfidf_matrix, df)
print(recommendations)
# Out:
# [{'movie_name': 'Resident Evil', 'year': 2002, 'runtime': 100, 'genre': 'Action', 'rating': 6.6, 'director': 'Paul W.S. Anderson', 'star': 'Milla Jovovich, \nMichelle Rodriguez, \nRyan McCluskey, \nOscar Pearce', 'votes': 275282.0, 'combined_features': 'Action Paul W.S. Anderson Milla Jovovich, \nMichelle Rodriguez, \nRyan McCluskey, \nOscar Pearce', 'similarity_score': 0.1717862828101169}, {'movie_name': 'Shimmer Lake', 'year': 2017, 'runtime': 86, 'genre': 'Action', 'rating': 6.3, 'director': 'Oren Uziel', 'star': 'Benjamin Walker, \nRainn Wilson, \nStephanie Sigman, \nJohn Michael Higgins', 'votes': 15483.0, 'combined_features': 'Action Oren Uziel Benjamin Walker, \nRainn Wilson, \nStephanie Sigman, \nJohn Michael Higgins', 'similarity_score': 0.17072420550588877}, {'movie_name': 'Juan of the Dead', 'year': 2011, 'runtime': 92, 'genre': 'Action', 'rating': 6.4, 'director': 'Alejandro Brugués', 'star': 'Alexis Díaz de Villegas, \nJorge Molina, \nAndros Perugorría, \nAndrea Duro', 'votes': 10681.0, 'combined_features': 'Action Alejandro Brugués Alexis Díaz de Villegas, \nJorge Molina, \nAndros Perugorría, \nAndrea Duro', 'similarity_score': 0.16980308317396214}, {'movie_name': 'Planet Terror', 'year': 2007, 'runtime': 105, 'genre': 'Action', 'rating': 7.1, 'director': 'Robert Rodriguez', 'star': 'Rose McGowan, \nFreddy Rodríguez, \nJosh Brolin, \nMarley Shelton', 'votes': 214239.0, 'combined_features': 'Action Robert Rodriguez Rose McGowan, \nFreddy Rodríguez, \nJosh Brolin, \nMarley Shelton', 'similarity_score': 0.16740690058799698}, {'movie_name': 'The Girl with All the Gifts', 'year': 2016, 'runtime': 111, 'genre': 'Action', 'rating': 6.6, 'director': 'Colm McCarthy', 'star': 'Sennia Nanua, \nFisayo Akinade, \nDominique Tipper, \nPaddy Considine', 'votes': 61293.0, 'combined_features': 'Action Colm McCarthy Sennia Nanua, \nFisayo Akinade, \nDominique Tipper, \nPaddy Considine', 'similarity_score': 0.16609075013890065}, {'movie_name': 'Bhaagamathie', 'year': 2018, 'runtime': 138, 'genre': 'Action', 'rating': 7.0, 'director': 'Ashok G.', 'star': 'Anushka Shetty, \nUnni Mukundan, \nJayaram, \nMurli Sharma', 'votes': 3184.0, 'combined_features': 'Action Ashok G. Anushka Shetty, \nUnni Mukundan, \nJayaram, \nMurli Sharma', 'similarity_score': 0.16470892080896518}, {'movie_name': 'Intacto', 'year': 2001, 'runtime': 108, 'genre': 'Action', 'rating': 6.8, 'director': 'Juan Carlos Fresnadillo', 'star': 'Max von Sydow, \nEusebio Poncela, \nLeonardo Sbaraglia, \nMónica López', 'votes': 13338.0, 'combined_features': 'Action Juan Carlos Fresnadillo Max von Sydow, \nEusebio Poncela, \nLeonardo Sbaraglia, \nMónica López', 'similarity_score': 0.16443582401986812}, {'movie_name': 'Bloody Hell', 'year': 2020, 'runtime': 93, 'genre': 'Action', 'rating': 6.6, 'director': 'Alister Grierson', 'star': "Ben O'Toole, \nMeg Fraser, \nCaroline Craig, \nMatthew Sunderland", 'votes': 8266.0, 'combined_features': "Action Alister Grierson Ben O'Toole, \nMeg Fraser, \nCaroline Craig, \nMatthew Sunderland", 'similarity_score': 0.16427768192338504}]
